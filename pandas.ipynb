# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'name': ['Aidar', 'Akti', 'Felix', 'Daniel'],
    'age' : [12, 20, 21, 22],
    'score' : [71, 24, 65,87]
})
df
# Out:
#      name  age  score
# 0   Aidar   12     71
# 1    Akti   20     24
# 2   Felix   21     65
# 3  Daniel   22     87

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     4 non-null      int64
#  2   score   4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df[['name']]
# Out:
#      name
# 0   Aidar
# 1    Akti
# 2   Felix
# 3  Daniel

# %%
df['name']
# Out:
# 0     Aidar
# 1      Akti
# 2     Felix
# 3    Daniel
# Name: name, dtype: object

# %%
print(df.loc[2])
print(df.iloc[2])
# Out:
# name     Felix
# age         21
# score       65
# Name: 2, dtype: object
# name     Felix
# age         21
# score       65
# Name: 2, dtype: object

# %%
df[df['age'] > 20]
# Out:
#      name  age  score
# 2   Felix   21     65
# 3  Daniel   22     87

# %%
df[df['score'] > 40]
# Out:
#      name  age  score
# 0   Aidar   12     71
# 2   Felix   21     65
# 3  Daniel   22     87

# %%
df['passed'] = df['score'] > 65

# %%
df['passed'] = df['passed'].map({True: 1, False: 0})

# %%
df
# Out:
#      name  age  score  passed
# 0   Aidar   12     71       1
# 1    Akti   20     24       0
# 2   Felix   21     65       0
# 3  Daniel   22     87       1

# %%
df['age_+_1'] = df['age'] + 1
df
# Out:
#      name  age  score  passed  age_+_1
# 0   Aidar   12     71       1       13
# 1    Akti   20     24       0       21
# 2   Felix   21     65       0       22
# 3  Daniel   22     87       1       23

# %%
df['age_plus_1'] = df['age'] + (df['age'] > 20)
df
# Out:
#      name  age  score  passed  age_+_1  age_plus_1
# 0   Aidar   12     71       1       13          12
# 1    Akti   20     24       0       21          20
# 2   Felix   21     65       0       22          22
# 3  Daniel   22     87       1       23          23

# %%
df[['age']]> 20
# Out:
#      age
# 0  False
# 1  False
# 2   True
# 3   True

# %%
df
# Out:
#      name  age  score  passed  age_+_1  age_plus_1
# 0   Aidar   12     71       1       13          12
# 1    Akti   20     24       0       21          20
# 2   Felix   21     65       0       22          22
# 3  Daniel   22     87       1       23          23

# %%
df['age']
# Out:
# 0    12
# 1    20
# 2    21
# 3    22
# Name: age, dtype: int64

# %%
df['age'] > 20
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: age, dtype: bool

# %%
df['age'] = df['age'] + (df['age'] > 23)
print(df['age'])
# Out:
# 0    12
# 1    20
# 2    21
# 3    22
# Name: age, dtype: int64

# %%
df['score'].isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# Name: score, dtype: bool

# %%
df.isna().sum()
# Out:
# name          0
# age           0
# score         0
# passed        0
# age_+_1       0
# age_plus_1    0
# dtype: int64

# %%
df["score"].fillna(df["score"].mean())
# Out:
# 0    71
# 1    24
# 2    65
# 3    87
# Name: score, dtype: int64

# %%
df.dropna()
# Out:
#      name  age  score  passed  age_+_1  age_plus_1
# 0   Aidar   12     71       1       13          12
# 1    Akti   20     24       0       21          20
# 2   Felix   21     65       0       22          22
# 3  Daniel   22     87       1       23          23

# %%
df.groupby("age")["score"].mean()
# Out:
# age
# 12    71.0
# 20    24.0
# 21    65.0
# 22    87.0
# Name: score, dtype: float64

# %%
df.groupby("age").agg(
    avg_score=("score", "mean"),
    count=("score", "count")
)
# Out:
#      avg_score  count
# age
# 12        71.0      1
# 20        24.0      1
# 21        65.0      1
# 22        87.0      1

# %%
df["age"].value_counts()
df["passed"].value_counts(normalize=True)
# Out:
# passed
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64

# %%
data = pd.DataFrame({
    "student": ["Ann", "Bob", "Clara", "Dan", "Eva"],
    "math": [78, 85, 90, 65, 88],
    "english": [82, 79, 91, 70, 86],
    "age": [20, 21, 20, 22, 21]
})

# %%
d.tail()
# Out:
#   student  math  english  age
# 0     Ann    78       82   20
# 1     Bob    85       79   21
# 2   Clara    90       91   20
# 3     Dan    65       70   22
# 4     Eva    88       86   21

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   student  5 non-null      object
#  1   math     5 non-null      int64
#  2   english  5 non-null      int64
#  3   age      5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 288.0+ bytes

# %%
data.shape
# Out:
# (5, 4)

# %%
data['math'] > 80
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# Name: math, dtype: bool

# %%
data['avg_score'] = data[['math']]

# %%
data.sort_values('avg_score', ascending=False)
# Out:
#   student  math  english  age  avg_score
# 0     Ann    78       82   20        NaN
# 1     Bob    85       79   21        NaN
# 2   Clara    90       91   20        NaN
# 3     Dan    65       70   22        NaN
# 4     Eva    88       86   21        NaN

# %%
data['avg_score']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: avg_score, dtype: float64

# %%
data['avg_score'] = (data['math'] + data['english']) / 2

# %%
data['avg_score'] = data['avg_score']

# %%
data
# Out:
#   student  math  english  age  avg_score
# 0     Ann    78       82   20       80.0
# 1     Bob    85       79   21       82.0
# 2   Clara    90       91   20       90.5
# 3     Dan    65       70   22       67.5
# 4     Eva    88       86   21       87.0
